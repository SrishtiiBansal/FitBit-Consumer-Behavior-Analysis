# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Weight data

# %%
Weight_data_df=pd.read_csv("/content/drive/MyDrive/Week 8/weightLogInfo_merged.csv")
Weight_data_df.head()
# Out:
#            Id                   Date    WeightKg  WeightPounds   Fat  \
# 0  1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1  1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2  1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3  2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4  2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
#
#          BMI  IsManualReport          LogId
# 0  22.650000            True  1462233599000
# 1  22.650000            True  1462319999000
# 2  47.540001           False  1460509732000
# 3  21.450001            True  1461283199000
# 4  21.690001            True  1463097599000

# %%
Weight_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              67 non-null     int64
#  1   Date            67 non-null     object
#  2   WeightKg        67 non-null     float64
#  3   WeightPounds    67 non-null     float64
#  4   Fat             2 non-null      float64
#  5   BMI             67 non-null     float64
#  6   IsManualReport  67 non-null     bool
#  7   LogId           67 non-null     int64
# dtypes: bool(1), float64(4), int64(2), object(1)
# memory usage: 3.9+ KB

# %%
# Convert 'Date' to datetime for better visualization
Weight_data_df['Date'] = pd.to_datetime(Weight_data_df['Date'])

# %%
Weight_data_df.isnull().sum()
# Out:
# Id                 0
# Date               0
# WeightKg           0
# WeightPounds       0
# Fat               65
# BMI                0
# IsManualReport     0
# LogId              0
# dtype: int64

# %%
Weight_data_df.fillna(Weight_data_df.median(), inplace=True)
# Out:
# <ipython-input-7-e44ba2d3c29e>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Weight_data_df.fillna(Weight_data_df.median(), inplace=True)

# %%
Weight_data_df.shape
# Out:
# (67, 8)

# %%
Weight_data_df.describe()
# Out:
#                  Id    WeightKg  WeightPounds        Fat        BMI  \
# count  6.700000e+01   67.000000     67.000000  67.000000  67.000000
# mean   7.009282e+09   72.035821    158.811801  23.500000  25.185224
# std    1.950322e+09   13.923206     30.695415   0.261116   3.066963
# min    1.503960e+09   52.599998    115.963147  22.000000  21.450001
# 25%    6.962181e+09   61.400002    135.363832  23.500000  23.959999
# 50%    6.962181e+09   62.500000    137.788914  23.500000  24.389999
# 75%    8.877689e+09   85.049999    187.503152  23.500000  25.559999
# max    8.877689e+09  133.500000    294.317120  25.000000  47.540001
#
#               LogId
# count  6.700000e+01
# mean   1.461772e+12
# std    7.829948e+08
# min    1.460444e+12
# 25%    1.461079e+12
# 50%    1.461802e+12
# 75%    1.462375e+12
# max    1.463098e+12

# %%
Weight_data_df.duplicated().sum()
# Out:
# 0

# %%
# Convert to Date and format
# Convert 'Date' to datetime format
Weight_data_df['Date'] = pd.to_datetime(Weight_data_df['Date'])
Weight_data_df['Date'] = pd.to_datetime(Weight_data_df['Date']).dt.strftime('%m/%d/%Y')
Weight_data_df['Date'] = Weight_data_df['Date'].str.replace('/', '-')

# %%
Weight_data_df.head()
# Out:
#            Id        Date    WeightKg  WeightPounds   Fat        BMI  \
# 0  1503960366  05-02-2016   52.599998    115.963147  22.0  22.650000
# 1  1503960366  05-03-2016   52.599998    115.963147  23.5  22.650000
# 2  1927972279  04-13-2016  133.500000    294.317120  23.5  47.540001
# 3  2873212765  04-21-2016   56.700001    125.002104  23.5  21.450001
# 4  2873212765  05-12-2016   57.299999    126.324875  23.5  21.690001
#
#    IsManualReport          LogId
# 0            True  1462233599000
# 1            True  1462319999000
# 2           False  1460509732000
# 3            True  1461283199000
# 4            True  1463097599000

# %% [markdown]
# #Heart Rate Data

# %%
Heart_Rate_df=pd.read_csv("/content/drive/MyDrive/Week 8/heartrate_seconds_merged.csv")
Heart_Rate_df.head()
# Out:
#            Id                  Time  Value
# 0  2022484408  4/12/2016 7:21:00 AM     97
# 1  2022484408  4/12/2016 7:21:05 AM    102
# 2  2022484408  4/12/2016 7:21:10 AM    105
# 3  2022484408  4/12/2016 7:21:20 AM    103
# 4  2022484408  4/12/2016 7:21:25 AM    101

# %%
Heart_Rate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2483658 entries, 0 to 2483657
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Id      int64
#  1   Time    object
#  2   Value   int64
# dtypes: int64(2), object(1)
# memory usage: 56.8+ MB

# %%
# Convert 'Time' to datetime for better visualization
Heart_Rate_df['Time'] = pd.to_datetime(Heart_Rate_df['Time'])

# %%
Heart_Rate_df.isnull().sum()
# Out:
# Id       0
# Time     0
# Value    0
# dtype: int64

# %%
Heart_Rate_df.shape
# Out:
# (2483658, 3)

# %%
Heart_Rate_df.duplicated().sum()
# Out:
# 0

# %%
Heart_Rate_df.drop_duplicates(inplace=True)
Heart_Rate_df.duplicated().sum()
# Out:
# 0

# %%
Heart_Rate_df.head()
# Out:
#            Id                Time  Value
# 0  2022484408 2016-04-12 07:21:00     97
# 1  2022484408 2016-04-12 07:21:05    102
# 2  2022484408 2016-04-12 07:21:10    105
# 3  2022484408 2016-04-12 07:21:20    103
# 4  2022484408 2016-04-12 07:21:25    101

# %%
Heart_Rate_df.describe()
# Out:
#                  Id         Value
# count  2.483658e+06  2.483658e+06
# mean   5.513765e+09  7.732842e+01
# std    1.950224e+09  1.940450e+01
# min    2.022484e+09  3.600000e+01
# 25%    4.388162e+09  6.300000e+01
# 50%    5.553957e+09  7.300000e+01
# 75%    6.962181e+09  8.800000e+01
# max    8.877689e+09  2.030000e+02

# %%
# Convert to Time and format
Heart_Rate_df['Time'] = pd.to_datetime(Heart_Rate_df['Time']).dt.strftime('%m/%d/%Y %I:%M %p')

# %%
Heart_Rate_df.head()
# Out:
#            Id                 Time  Value
# 0  2022484408  04-12-2016 07:21 AM     97
# 1  2022484408  04-12-2016 07:21 AM    102
# 2  2022484408  04-12-2016 07:21 AM    105
# 3  2022484408  04-12-2016 07:21 AM    103
# 4  2022484408  04-12-2016 07:21 AM    101

# %%
#Save the merged dataset to a new CSV file
Weight_data_df.to_csv("/content/Weight_dataset.csv", index=False)

Heart_Rate_df.to_csv("/content/HeartRate_dataset.csv", index=False)

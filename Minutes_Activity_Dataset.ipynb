# %% [markdown]
# <a href="https://colab.research.google.com/github/SrishtiiBansal/FitBit-Consumer-Behavior-Analysis/blob/main/Minutes_Activity_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Minutes Activity dataset

# %%
minute_Calories_Narrow_df=pd.read_csv("/content/drive/MyDrive/Prepinsta Projects/Week 8 /minuteCaloriesNarrow_merged.csv")
minute_Intensities_Narrow_df=pd.read_csv("/content/drive/MyDrive/Prepinsta Projects/Week 8 /minuteIntensitiesNarrow_merged.csv")
minute_METs_Narrow_df=pd.read_csv("/content/drive/MyDrive/Prepinsta Projects/Week 8 /minuteMETsNarrow_merged.csv")
minute_Steps_Narrow_df=pd.read_csv("/content/drive/MyDrive/Prepinsta Projects/Week 8 /minuteStepsNarrow_merged.csv")

# Merge datasets
merged_df = pd.merge(minute_Calories_Narrow_df, minute_Intensities_Narrow_df, on=['Id', 'ActivityMinute'], how='outer')
merged_df = pd.merge(merged_df, minute_METs_Narrow_df, on=['Id', 'ActivityMinute'], how='outer')
Minute_Activity_merged_df = pd.merge(merged_df, minute_Steps_Narrow_df, on=['Id', 'ActivityMinute'], how='outer')

Minute_Activity_merged_df.head()
# Out:
#            Id         ActivityMinute  Calories  Intensity  METs  Steps
# 0  1503960366  4/12/2016 12:00:00 AM    0.7865          0    10      0
# 1  1503960366  4/12/2016 12:01:00 AM    0.7865          0    10      0
# 2  1503960366  4/12/2016 12:02:00 AM    0.7865          0    10      0
# 3  1503960366  4/12/2016 12:03:00 AM    0.7865          0    10      0
# 4  1503960366  4/12/2016 12:04:00 AM    0.7865          0    10      0

# %%
Minute_Activity_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1325580 entries, 0 to 1325579
# Data columns (total 6 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   Id              1325580 non-null  int64
#  1   ActivityMinute  1325580 non-null  object
#  2   Calories        1325580 non-null  float64
#  3   Intensity       1325580 non-null  int64
#  4   METs            1325580 non-null  int64
#  5   Steps           1325580 non-null  int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 70.8+ MB

# %%
Minute_Activity_merged_df['ActivityMinute'] = pd.to_datetime(Minute_Activity_merged_df['ActivityMinute'])

# %%
Minute_Activity_merged_df.isnull().sum()
# Out:
# Id                0
# ActivityMinute    0
# Calories          0
# Intensity         0
# METs              0
# Steps             0
# dtype: int64

# %%
Minute_Activity_merged_df.shape
# Out:
# (1325580, 6)

# %%
Minute_Activity_merged_df.duplicated().sum()
# Out:
# 0

# %%
Minute_Activity_merged_df.describe()
# Out:
#                  Id      Calories     Intensity          METs         Steps
# count  1.325580e+06  1.325580e+06  1.325580e+06  1.325580e+06  1.325580e+06
# mean   4.847898e+09  1.623130e+00  2.005937e-01  1.469001e+01  5.336192e+00
# std    2.422313e+09  1.410447e+00  5.190227e-01  1.205541e+01  1.812830e+01
# min    1.503960e+09  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.320127e+09  9.357000e-01  0.000000e+00  1.000000e+01  0.000000e+00
# 50%    4.445115e+09  1.217600e+00  0.000000e+00  1.000000e+01  0.000000e+00
# 75%    6.962181e+09  1.432700e+00  0.000000e+00  1.100000e+01  0.000000e+00
# max    8.877689e+09  1.974995e+01  3.000000e+00  1.570000e+02  2.200000e+02

# %%
# Convert to ActivityMinute and format
# Replace '/' with '-'

Minute_Activity_merged_df['ActivityMinute'] = pd.to_datetime(Minute_Activity_merged_df['ActivityMinute']).dt.strftime('%m/%d/%Y %I:%M %p')
Minute_Activity_merged_df['ActivityMinute'] = Minute_Activity_merged_df['ActivityMinute'].str.replace('/', '-')

# %%
Minute_Activity_merged_df.head(1000)
# Out:
#              Id       ActivityMinute  Calories  Intensity  METs  Steps
# 0    1503960366  04-12-2016 12:00 AM    0.7865          0    10      0
# 1    1503960366  04-12-2016 12:01 AM    0.7865          0    10      0
# 2    1503960366  04-12-2016 12:02 AM    0.7865          0    10      0
# 3    1503960366  04-12-2016 12:03 AM    0.7865          0    10      0
# 4    1503960366  04-12-2016 12:04 AM    0.7865          0    10      0
# ..          ...                  ...       ...        ...   ...    ...
# 995  1503960366  04-12-2016 04:35 PM    1.8876          1    24      4
# 996  1503960366  04-12-2016 04:36 PM    0.9438          0    12      0
# 997  1503960366  04-12-2016 04:37 PM    0.9438          0    12      0
# 998  1503960366  04-12-2016 04:38 PM    0.9438          0    12      0
# 999  1503960366  04-12-2016 04:39 PM    0.9438          0    12      0
#
# [1000 rows x 6 columns]

# %%
#Save the merged dataset to a new CSV file
Minute_Activity_merged_df.to_csv("/content/Minute_Activity_merged_dataset.csv", index=False)
